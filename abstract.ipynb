# %%
# pip install pipecat pipecatcloud -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/e0/f9/0595336914c5619e5f28a1fb793285925a8cd4b432c9da0a987836c7f822/shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# ...
#   Created wheel for pipecat: filename=pipecat-0.3.0-py3-none-any.whl size=30525 sha256=5b746d8c189c19f8e4ae52739bc04566590f14efb773cffed9742f4ff3a11f97
#   Stored in directory: c:\users\oranste\appdata\local\pip\cache\wheels\72\c6\2e\73534ee0468431db6148f9e9190030b9023a43dcceaa558510
# Successfully built pipecat
# ...
#
#    ------ ---------------------------------  4/25 [shellingham]
#    -------------- -------------------------  9/25 [flexcache]
#    ----------------- ---------------------- 11/25 [annotated-doc]
#    ---------------------- ----------------- 14/25 [uvicorn]
#    ------------------------ --------------- 15/25 [starlette]
# ...

# %%
#pip install brotli
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip requests
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
# ...

# %%
# !cerebrium init voice-agent
# Out:
# Cerebrium CLI binary not found. Installing...
#
# ...
#
#   Downloading: 0.0/4.2 MB (0%)
#   Downloading: 0.0/4.2 MB (0%)
#   Downloading: 0.0/4.2 MB (1%)
#   Downloading: 0.0/4.2 MB (1%)
#   Downloading: 0.0/4.2 MB (1%)
#   Downloading: 0.0/4.2 MB (1%)
#   Downloading: 0.1/4.2 MB (1%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (2%)
#   Downloading: 0.1/4.2 MB (3%)
#   Downloading: 0.1/4.2 MB (3%)
#   Downloading: 0.1/4.2 MB (3%)
#   Downloading: 0.1/4.2 MB (3%)
#   Downloading: 0.1/4.2 MB (3%)
#   Downloading: 0.1/4.2 MB (4%)
#   Downloading: 0.2/4.2 MB (4%)
#   Downloading: 0.2/4.2 MB (4%)
#   Downloading: 0.2/4.2 MB (4%)
#   Downloading: 0.2/4.2 MB (4%)
#   Downloading: 0.2/4.2 MB (5%)
#   Downloading: 0.2/4.2 MB (5%)
#   Downloading: 0.2/4.2 MB (5%)
#   Downloading: 0.2/4.2 MB (5%)
#   Downloading: 0.2/4.2 MB (5%)
# ...

# %%
pip install cerebrium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/c4/b5/3cb612a51a0915e76124f7e32a32a328ba84a4c3ad322a7d2144553d159e/cerebrium-2.5.0-py3-none-any.whl.metadata
