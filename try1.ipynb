# %% [markdown]
# 这套工具基于 Pipecat 框架，链路：
# 语音输入 (麦克风) → Deepgram 语音转文字 (STT) → OpenAI 大模型处理日历逻辑 → Cartesia 文字转语音 (TTS) → 语音输出
# 全程实时语音交互，最终实现语音创建 / 查询日历。
# 1. Pipecat 项目（pipecat-quickstart）
# 负责语音交互链路：麦克风收音 → 语音转文字 (Deepgram) → 大模型处理 → 语音播报 (Cartesia)，是语音能力底座。
# 2. Cerebrium 项目（voice-agent）
# 用于后续云端部署、托管服务
